# %% [markdown]
# UTKFace dataset is a large-scale face dataset with long age span (range from 0 to 116 years old). The dataset consists of over 20,000 face images with annotations of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc. This dataset could be used on a variety of tasks, e.g., face detection, age estimation, age progression/regression, landmark localization, etc.
#
# The labels of each face image is embedded in the file name, formated like [age]_[gender]_[race]_[date&time].jpg
#
# [age] is an integer from 0 to 116, indicating the age
# [gender] is either 0 (male) or 1 (female)
# [race] is an integer from 0 to 4, denoting White, Black, Asian, Indian, and Others (like Hispanic, Latino, Middle Eastern).
# [date&time] is in the format of yyyymmddHHMMSSFFF, showing the date and time an image was collected to UTKFace

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%bash
# ls data
# # it seems crop_part1 conists of subset of data contained in UTKFace so we won't be using it.
# Out:
# UTKFace
# UTKFace.tar.gz

# %% [markdown]
# **Constants**

# %%
DATA_DIR = "data/UTKFace"
TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198
ID_GENDER_MAP = {0: 'male', 1: 'female'}
GENDER_ID_MAP = dict((g, i) for i, g in ID_GENDER_MAP.items())
ID_RACE_MAP = {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'}
RACE_ID_MAP = dict((r, i) for i, r in ID_RACE_MAP.items())

ID_GENDER_MAP, GENDER_ID_MAP, ID_RACE_MAP, RACE_ID_MAP
# Out:
# ({0: 'male', 1: 'female'},
#  {'male': 0, 'female': 1},
#  {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
#  {'white': 0, 'black': 1, 'asian': 2, 'indian': 3, 'others': 4})

# %%
def parse_filepath(filepath):
    try:
        path, filename = os.path.split(filepath)
        filename, ext = os.path.splitext(filename)
        age, gender, race, _ = filename.split("_")
        return int(age), ID_GENDER_MAP[int(gender)], ID_RACE_MAP[int(race)]
    except Exception as e:
        print(filepath)
        return None, None, None

# %%
# create a pandas data frame of images, age, gender and race
files = glob.glob(os.path.join(DATA_DIR, "*.jpg"))

# %%
attributes = list(map(parse_filepath, files))
# Out:
# data/UTKFace/39_1_20170116174525125.jpg.chip.jpg
# data/UTKFace/61_1_20170109150557335.jpg.chip.jpg
# data/UTKFace/61_1_20170109142408075.jpg.chip.jpg

# %%
df = pd.DataFrame(attributes)
df['file'] = files
df.columns = ['age', 'gender', 'race', 'file']
df = df.dropna()
df.head()
# Out:
#     age  gender    race                                               file
# 0  65.0    male  indian  data/UTKFace/65_0_3_20170119205206575.jpg.chip...
# 1  16.0    male   white  data/UTKFace/16_0_0_20170110232429214.jpg.chip...
# 2  52.0    male   white  data/UTKFace/52_0_0_20170111195726274.jpg.chip...
# 3  18.0  female   white  data/UTKFace/18_1_0_20170109212921724.jpg.chip...
# 4  57.0  female   white  data/UTKFace/57_1_0_20170120221057091.jpg.chip...

# %% [markdown]
# # Exploratory analysis

# %%
df.describe()
# Out:
#                 age
# count  23705.000000
# mean      33.300907
# std       19.885708
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %% [markdown]
# From the plot we can see that most of people are within 10 and 55 years of age. Most probably, we'll discard the dataset for rest of the ages.

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='gender', y='age', hue='race')

# %%
df.groupby(by=['race', 'gender'])['age'].count().plot(kind='bar')

# %% [markdown]
# It turns out that there are many images of *white male* and *while female*. images from *others* category are very less in number compared to rest of the categories especially *white* category.
# Let's analyze our data from *age* perspective.

# %%
df['age'].hist()

# %%
df['age'].describe()
# Out:
# count    23705.000000
# mean        33.300907
# std         19.885708
# min          1.000000
# 25%         23.000000
# 50%         29.000000
# 75%         45.000000
# max        116.000000
# Name: age, dtype: float64

# %%
df = df[(df['age'] > 10) & (df['age'] < 65)]

# %% [markdown]
# # Data prep

# %%
p = np.random.RandomState(seed=10).permutation(len(df))
print(p[:10])
train_up_to = int(len(df) * TRAIN_TEST_SPLIT)
train_idx = p[:train_up_to]
test_idx = p[train_up_to:]

# split train_idx further into training and validation set
train_up_to = int(train_up_to * 0.7)
train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]

df['gender_id'] = df['gender'].map(lambda gender: GENDER_ID_MAP[gender])
df['race_id'] = df['race'].map(lambda race: RACE_ID_MAP[race])

max_age = df['age'].max()
len(train_idx), len(valid_idx), len(test_idx), max_age
# Out:
# [15086  9370   344 16273  2785  9942 17434 13043  1135  5649]
# (9079, 3891, 5559, 64.0)

# %%
from keras.utils import to_categorical
from PIL import Image

def get_data_generator(df, indices, for_training, batch_size=16):
    images, ages, races, genders = [], [], [], []
    while True:
        for i in indices:
            r = df.iloc[i]
            file, age, race, gender = r['file'], r['age'], r['race_id'], r['gender_id']
            im = Image.open(file)
            im = im.resize((IM_WIDTH, IM_HEIGHT))
            im = np.array(im) / 255.0
            images.append(im)
            ages.append(age / max_age)
            races.append(to_categorical(race, len(RACE_ID_MAP)))
            genders.append(to_categorical(gender, 2))
            if len(images) >= batch_size:
                yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
                images, ages, races, genders = [], [], [], []
        if not for_training:
            break
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Model training

# %%
from keras.layers import Input, Dense, BatchNormalization, Conv2D, MaxPool2D, GlobalMaxPool2D, Dropout, Flatten
from keras.optimizers import SGD, RMSprop
from keras.models import Model
from keras import applications

vgg_model = applications.VGG16(weights='imagenet',
                               include_top=False,
                               input_shape=(IM_HEIGHT, IM_WIDTH, 3))

#Branching out earlier in the model for race
layer_dict = dict([(layer.name, layer) for layer in vgg_model.layers])
x_race = layer_dict['block3_pool'].output
x_race = Flatten()(x_race)

#More layers till the last layer in VGG for age and gender
x = vgg_model.output
x = Flatten()(x)
x = Dense(4096, activation='relu')(x)

# for age calculation
age = Dense(units=128, activation='relu')(x)
age_output = Dense(units=1, activation='sigmoid', name='age_output')(age)

# for race prediction
race = Dense(units=128, activation='relu')(x_race)
race_output = Dense(units=len(RACE_ID_MAP), activation='softmax', name='race_output')(race)

# for gender prediction
gender = Dense(units=128, activation='relu')(x)
gender_output = Dense(units=len(GENDER_ID_MAP), activation='softmax', name='gender_output')(gender)

model = Model(inputs=vgg_model.input, outputs=[age_output, race_output, gender_output])
opt = RMSprop(lr=1e-5)
model.compile(optimizer=opt, 
              loss={'age_output': 'mse', 'race_output': 'categorical_crossentropy', 'gender_output': 'categorical_crossentropy'},
              loss_weights={'age_output': 1., 'race_output': -1., 'gender_output': 1.},
              metrics={'age_output': 'mae', 'race_output': 'accuracy', 'gender_output': 'accuracy'})
# model.summary()

# %%
from keras.callbacks import ModelCheckpoint

batch_size = 64
valid_batch_size = 64
train_gen = get_data_generator(df, train_idx, for_training=True, batch_size=batch_size)
valid_gen = get_data_generator(df, valid_idx, for_training=True, batch_size=valid_batch_size)

callbacks = [
    ModelCheckpoint("./models/weighted_forked_VGG_model.h5", monitor='val_loss')
]

history = model.fit_generator(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=10,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size)
# Out:
# Epoch 1/10
# 141/141 [==============================] - 55s 393ms/step - loss: -12.1870 - age_output_loss: 0.0287 - race_output_loss: 12.5720 - gender_output_loss: 0.3563 - age_output_mean_absolute_error: 0.1338 - race_output_acc: 0.2200 - gender_output_acc: 0.8392 - val_loss: -12.1868 - val_age_output_loss: 0.0215 - val_race_output_loss: 12.4076 - val_gender_output_loss: 0.1993 - val_age_output_mean_absolute_error: 0.1154 - val_race_output_acc: 0.2302 - val_gender_output_acc: 0.9302
# Epoch 2/10
# 141/141 [==============================] - 48s 343ms/step - loss: -12.3771 - age_output_loss: 0.0221 - race_output_loss: 12.5655 - gender_output_loss: 0.1663 - age_output_mean_absolute_error: 0.1166 - race_output_acc: 0.2204 - gender_output_acc: 0.9383 - val_loss: -12.2259 - val_age_output_loss: 0.0188 - val_race_output_loss: 12.4118 - val_gender_output_loss: 0.1670 - val_age_output_mean_absolute_error: 0.1050 - val_race_output_acc: 0.2299 - val_gender_output_acc: 0.9424
# Epoch 3/10
# 141/141 [==============================] - 48s 343ms/step - loss: -12.4445 - age_output_loss: 0.0181 - race_output_loss: 12.5690 - gender_output_loss: 0.1065 - age_output_mean_absolute_error: 0.1054 - race_output_acc: 0.2202 - gender_output_acc: 0.9628 - val_loss: -12.2267 - val_age_output_loss: 0.0182 - val_race_output_loss: 12.4076 - val_gender_output_loss: 0.1626 - val_age_output_mean_absolute_error: 0.1024 - val_race_output_acc: 0.2302 - val_gender_output_acc: 0.9437
# Epoch 4/10
# 141/141 [==============================] - 48s 344ms/step - loss: -12.4751 - age_output_loss: 0.0155 - race_output_loss: 12.5601 - gender_output_loss: 0.0696 - age_output_mean_absolute_error: 0.0971 - race_output_acc: 0.2207 - gender_output_acc: 0.9773 - val_loss: -12.2456 - val_age_output_loss: 0.0174 - val_race_output_loss: 12.4328 - val_gender_output_loss: 0.1697 - val_age_output_mean_absolute_error: 0.1041 - val_race_output_acc: 0.2286 - val_gender_output_acc: 0.9451
# Epoch 5/10
# 141/141 [==============================] - 49s 346ms/step - loss: -12.5066 - age_output_loss: 0.0137 - race_output_loss: 12.5655 - gender_output_loss: 0.0452 - age_output_mean_absolute_error: 0.0911 - race_output_acc: 0.2204 - gender_output_acc: 0.9852 - val_loss: -12.2274 - val_age_output_loss: 0.0171 - val_race_output_loss: 12.4286 - val_gender_output_loss: 0.1841 - val_age_output_mean_absolute_error: 0.1006 - val_race_output_acc: 0.2289 - val_gender_output_acc: 0.9443
# Epoch 6/10
# 141/141 [==============================] - 49s 346ms/step - loss: -12.5245 - age_output_loss: 0.0120 - race_output_loss: 12.5655 - gender_output_loss: 0.0289 - age_output_mean_absolute_error: 0.0852 - race_output_acc: 0.2204 - gender_output_acc: 0.9915 - val_loss: -12.1792 - val_age_output_loss: 0.0168 - val_race_output_loss: 12.3950 - val_gender_output_loss: 0.1990 - val_age_output_mean_absolute_error: 0.0981 - val_race_output_acc: 0.2310 - val_gender_output_acc: 0.9458
# Epoch 7/10
# 141/141 [==============================] - 49s 349ms/step - loss: -12.5475 - age_output_loss: 0.0110 - race_output_loss: 12.5744 - gender_output_loss: 0.0159 - age_output_mean_absolute_error: 0.0815 - race_output_acc: 0.2199 - gender_output_acc: 0.9961 - val_loss: -12.1940 - val_age_output_loss: 0.0165 - val_race_output_loss: 12.4118 - val_gender_output_loss: 0.2012 - val_age_output_mean_absolute_error: 0.0992 - val_race_output_acc: 0.2299 - val_gender_output_acc: 0.9521
# Epoch 8/10
# 141/141 [==============================] - 51s 358ms/step - loss: -12.5468 - age_output_loss: 0.0086 - race_output_loss: 12.5673 - gender_output_loss: 0.0119 - age_output_mean_absolute_error: 0.0717 - race_output_acc: 0.2203 - gender_output_acc: 0.9958 - val_loss: -12.1371 - val_age_output_loss: 0.0188 - val_race_output_loss: 12.4076 - val_gender_output_loss: 0.2517 - val_age_output_mean_absolute_error: 0.1085 - val_race_output_acc: 0.2302 - val_gender_output_acc: 0.9482
# Epoch 9/10
# 141/141 [==============================] - 49s 350ms/step - loss: -12.5518 - age_output_loss: 0.0083 - race_output_loss: 12.5708 - gender_output_loss: 0.0108 - age_output_mean_absolute_error: 0.0705 - race_output_acc: 0.2201 - gender_output_acc: 0.9966 - val_loss: -12.1334 - val_age_output_loss: 0.0172 - val_race_output_loss: 12.4202 - val_gender_output_loss: 0.2696 - val_age_output_mean_absolute_error: 0.0993 - val_race_output_acc: 0.2294 - val_gender_output_acc: 0.9500
# Epoch 10/10
# 141/141 [==============================] - 49s 350ms/step - loss: -12.5349 - age_output_loss: 0.0071 - race_output_loss: 12.5548 - gender_output_loss: 0.0128 - age_output_mean_absolute_error: 0.0656 - race_output_acc: 0.2211 - gender_output_acc: 0.9965 - val_loss: -12.1227 - val_age_output_loss: 0.0210 - val_race_output_loss: 12.3950 - val_gender_output_loss: 0.2513 - val_age_output_mean_absolute_error: 0.1083 - val_race_output_acc: 0.2310 - val_gender_output_acc: 0.9482

# %%
def  plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['race_output_acc'], label='Race Train accuracy')
    axes[0].plot(history.history['val_race_output_acc'], label='Race Val accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()
    
    axes[1].plot(history.history['gender_output_acc'], label='Gender Train accuracy')
    axes[1].plot(history.history['val_gender_output_acc'], label='Gener Val accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['age_output_mean_absolute_error'], label='Age Train MAE')
    axes[2].plot(history.history['val_age_output_mean_absolute_error'], label='Age Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
dict(zip(model.metrics_names, model.evaluate_generator(test_gen, steps=len(test_idx)//128)))
# Out:
# {'loss': -12.297311605409135,
#  'age_output_loss': 0.020942377619618594,
#  'race_output_loss': 12.548335607661757,
#  'gender_output_loss': 0.23008162935459336,
#  'age_output_mean_absolute_error': 0.10928289003150407,
#  'race_output_acc': 0.2214752906976744,
#  'gender_output_acc': 0.9565770348837209}

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
x_test, (age_true, race_true, gender_true)= next(test_gen)
age_pred, race_pred, gender_pred = model.predict_on_batch(x_test)

# %%
race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)
age_true = age_true * max_age
age_pred = age_pred * max_age

# %%
from sklearn.metrics import classification_report
print("Classification report for race")
print(classification_report(race_true, race_pred))

print("\nClassification report for gender")
print(classification_report(gender_true, gender_pred))
# Out:
# Classification report for race
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        42
#            1       0.26      1.00      0.41        33
#            2       0.00      0.00      0.00        15
#            3       0.00      0.00      0.00        30
#            4       0.00      0.00      0.00         8
#
#    micro avg       0.26      0.26      0.26       128
#    macro avg       0.05      0.20      0.08       128
# weighted avg       0.07      0.26      0.11       128
#
#
# Classification report for gender
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95        75
#            1       0.93      0.94      0.93        53
#
#    micro avg       0.95      0.95      0.95       128
#    macro avg       0.94      0.95      0.94       128
# weighted avg       0.95      0.95      0.95       128
# /home/indu/tfenv/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import math
n = 30
random_indices = np.random.permutation(n)
n_cols = 5
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 20))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(x_test[img_idx])
    ax.set_title('a:{}, g:{}, r:{}'.format(int(age_pred[img_idx]), ID_GENDER_MAP[gender_pred[img_idx]], ID_RACE_MAP[race_pred[img_idx]]))
    ax.set_xlabel('a:{}, g:{}, r:{}'.format(int(age_true[img_idx]), ID_GENDER_MAP[gender_true[img_idx]], ID_RACE_MAP[race_true[img_idx]]))
    ax.set_xticks([])
    ax.set_yticks([])
