# %% [markdown]
# UTKFace dataset is a large-scale face dataset with long age span (range from 0 to 116 years old). The dataset consists of over 20,000 face images with annotations of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc. This dataset could be used on a variety of tasks, e.g., face detection, age estimation, age progression/regression, landmark localization, etc.
#
# The labels of each face image is embedded in the file name, formated like [age]_[gender]_[race]_[date&time].jpg
#
# [age] is an integer from 0 to 116, indicating the age
# [gender] is either 0 (male) or 1 (female)
# [race] is an integer from 0 to 4, denoting White, Black, Asian, Indian, and Others (like Hispanic, Latino, Middle Eastern).
# [date&time] is in the format of yyyymmddHHMMSSFFF, showing the date and time an image was collected to UTKFace

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%bash
# ls data
# # it seems crop_part1 conists of subset of data contained in UTKFace so we won't be using it.
# Out:
# UTKFace
# UTKFace.tar.gz

# %% [markdown]
# **Constants**

# %%
DATA_DIR = "data/UTKFace"
TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198
ID_GENDER_MAP = {0: 'male', 1: 'female'}
GENDER_ID_MAP = dict((g, i) for i, g in ID_GENDER_MAP.items())
ID_RACE_MAP = {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'}
RACE_ID_MAP = dict((r, i) for i, r in ID_RACE_MAP.items())

ID_GENDER_MAP, GENDER_ID_MAP, ID_RACE_MAP, RACE_ID_MAP
# Out:
# ({0: 'male', 1: 'female'},
#  {'male': 0, 'female': 1},
#  {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
#  {'white': 0, 'black': 1, 'asian': 2, 'indian': 3, 'others': 4})

# %%
def parse_filepath(filepath):
    try:
        path, filename = os.path.split(filepath)
        filename, ext = os.path.splitext(filename)
        age, gender, race, _ = filename.split("_")
        return int(age), ID_GENDER_MAP[int(gender)], ID_RACE_MAP[int(race)]
    except Exception as e:
        print(filepath)
        return None, None, None

# %%
# create a pandas data frame of images, age, gender and race
files = glob.glob(os.path.join(DATA_DIR, "*.jpg"))

# %%
attributes = list(map(parse_filepath, files))
# Out:
# data/UTKFace/39_1_20170116174525125.jpg.chip.jpg
# data/UTKFace/61_1_20170109150557335.jpg.chip.jpg
# data/UTKFace/61_1_20170109142408075.jpg.chip.jpg

# %%
df = pd.DataFrame(attributes)
df['file'] = files
df.columns = ['age', 'gender', 'race', 'file']
df = df.dropna()
df.head()
# Out:
#     age  gender    race                                               file
# 0  65.0    male  indian  data/UTKFace/65_0_3_20170119205206575.jpg.chip...
# 1  16.0    male   white  data/UTKFace/16_0_0_20170110232429214.jpg.chip...
# 2  52.0    male   white  data/UTKFace/52_0_0_20170111195726274.jpg.chip...
# 3  18.0  female   white  data/UTKFace/18_1_0_20170109212921724.jpg.chip...
# 4  57.0  female   white  data/UTKFace/57_1_0_20170120221057091.jpg.chip...

# %% [markdown]
# # Exploratory analysis

# %%
df.describe()
# Out:
#                 age
# count  23705.000000
# mean      33.300907
# std       19.885708
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %% [markdown]
# From the plot we can see that most of people are within 10 and 55 years of age. Most probably, we'll discard the dataset for rest of the ages.

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='gender', y='age', hue='race')

# %%
df.groupby(by=['race', 'gender'])['age'].count().plot(kind='bar')

# %% [markdown]
# It turns out that there are many images of *white male* and *while female*. images from *others* category are very less in number compared to rest of the categories especially *white* category.
# Let's analyze our data from *age* perspective.

# %%
df['age'].hist()

# %%
df.groupby(by=['race'])['race'].count().plot(kind='bar')

# %%
df['age'].describe()
# Out:
# count    23705.000000
# mean        33.300907
# std         19.885708
# min          1.000000
# 25%         23.000000
# 50%         29.000000
# 75%         45.000000
# max        116.000000
# Name: age, dtype: float64

# %%
df = df[(df['age'] > 10) & (df['age'] < 65)]

# %% [markdown]
# # Data prep

# %%
p = np.random.permutation(len(df))
train_up_to = int(len(df) * TRAIN_TEST_SPLIT)
train_idx = p[:train_up_to]
test_idx = p[train_up_to:]

# split train_idx further into training and validation set
train_up_to = int(train_up_to * 0.7)
train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]

df['gender_id'] = df['gender'].map(lambda gender: GENDER_ID_MAP[gender])
df['race_id'] = df['race'].map(lambda race: RACE_ID_MAP[race])

max_age = df['age'].max()
len(train_idx), len(valid_idx), len(test_idx), max_age
# Out:
# (9079, 3891, 5559, 64.0)

# %%
from keras.utils import to_categorical
from PIL import Image

def get_data_generator(df, indices, for_training, batch_size=16):
    images, ages, races, genders = [], [], [], []
    while True:
        for i in indices:
            r = df.iloc[i]
            file, age, race, gender = r['file'], r['age'], r['race_id'], r['gender_id']
            im = Image.open(file)
            im = im.resize((IM_WIDTH, IM_HEIGHT))
            im = np.array(im) / 255.0
            images.append(im)
            ages.append(age / max_age)
            races.append(to_categorical(race, len(RACE_ID_MAP)))
            genders.append(to_categorical(gender, 2))
            if len(images) >= batch_size:
                yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
                images, ages, races, genders = [], [], [], []
        if not for_training:
            break

# %% [markdown]
# # Model training

# %%
from keras.layers import Input, Dense, BatchNormalization, Conv2D, MaxPool2D, GlobalMaxPool2D, Dropout
from keras.optimizers import SGD
from keras.models import Model
import keras.backend as K

def conv_block(inp, filters=32, bn=True, pool=True):
    _ = Conv2D(filters=filters, kernel_size=3, activation='relu')(inp)
    if bn:
        _ = BatchNormalization()(_)
    if pool:
        _ = MaxPool2D()(_)
    return _

input_layer = Input(shape=(IM_HEIGHT, IM_WIDTH, 3))
_ = conv_block(input_layer, filters=32, bn=False, pool=False)
_ = conv_block(_, filters=32*2)
_ = conv_block(_, filters=32*3)
_ = conv_block(_, filters=32*4)
_ = conv_block(_, filters=32*5)
_ = conv_block(_, filters=32*6)
bottleneck = GlobalMaxPool2D()(_)

# for age calculation
_ = Dense(units=128, activation='relu')(bottleneck)
age_output = Dense(units=1, activation='sigmoid', name='age_output')(_)

# for race prediction
_ = Dense(units=128, activation='relu')(bottleneck)
race_output = Dense(units=len(RACE_ID_MAP), activation='softmax', name='race_output')(_)

# for gender prediction
_ = Dense(units=128, activation='relu')(bottleneck)
gender_output = Dense(units=len(GENDER_ID_MAP), activation='softmax', name='gender_output')(_)

model = Model(inputs=input_layer, outputs=[age_output, race_output, gender_output])
model.compile(optimizer='rmsprop', 
              loss={'age_output': 'mse', 'race_output': 'categorical_crossentropy', 'gender_output': 'categorical_crossentropy'},
              loss_weights={'age_output': 1., 'race_output': -1., 'gender_output': 1.},
              metrics={'age_output': 'mae', 'race_output': 'accuracy', 'gender_output': 'accuracy'})
# model.summary()

# %%
from keras.callbacks import ModelCheckpoint

batch_size = 64
valid_batch_size = 64
train_gen = get_data_generator(df, train_idx, for_training=True, batch_size=batch_size)
valid_gen = get_data_generator(df, valid_idx, for_training=True, batch_size=valid_batch_size)

callbacks = [
    ModelCheckpoint("models/weighted_model25eps.h5", monitor='val_loss')
]

history = model.fit_generator(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=25,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size)
# Out:
# Epoch 1/25
# 141/141 [==============================] - 23s 166ms/step - loss: -11.7549 - age_output_loss: 0.0742 - race_output_loss: 12.4346 - gender_output_loss: 0.6056 - age_output_mean_absolute_error: 0.2185 - race_output_acc: 0.2240 - gender_output_acc: 0.7538 - val_loss: -11.9510 - val_age_output_loss: 0.0552 - val_race_output_loss: 12.4076 - val_gender_output_loss: 0.4013 - val_age_output_mean_absolute_error: 0.1841 - val_race_output_acc: 0.2302 - val_gender_output_acc: 0.8430
# Epoch 2/25
# 141/141 [==============================] - 21s 152ms/step - loss: -12.1748 - age_output_loss: 0.0361 - race_output_loss: 12.5133 - gender_output_loss: 0.3025 - age_output_mean_absolute_error: 0.1517 - race_output_acc: 0.2236 - gender_output_acc: 0.8706 - val_loss: -11.9923 - val_age_output_loss: 0.0662 - val_race_output_loss: 12.4034 - val_gender_output_loss: 0.3449 - val_age_output_mean_absolute_error: 0.2081 - val_race_output_acc: 0.2305 - val_gender_output_acc: 0.8552
# Epoch 3/25
# 141/141 [==============================] - 21s 152ms/step - loss: -12.2500 - age_output_loss: 0.0304 - race_output_loss: 12.5083 - gender_output_loss: 0.2280 - age_output_mean_absolute_error: 0.1382 - race_output_acc: 0.2240 - gender_output_acc: 0.9121 - val_loss: -12.1384 - val_age_output_loss: 0.0279 - val_race_output_loss: 12.4244 - val_gender_output_loss: 0.2580 - val_age_output_mean_absolute_error: 0.1295 - val_race_output_acc: 0.2292 - val_gender_output_acc: 0.9036
# Epoch 4/25
# 141/141 [==============================] - 21s 152ms/step - loss: -12.2937 - age_output_loss: 0.0284 - race_output_loss: 12.5083 - gender_output_loss: 0.1861 - age_output_mean_absolute_error: 0.1336 - race_output_acc: 0.2240 - gender_output_acc: 0.9320 - val_loss: -12.1047 - val_age_output_loss: 0.0440 - val_race_output_loss: 12.4034 - val_gender_output_loss: 0.2547 - val_age_output_mean_absolute_error: 0.1615 - val_race_output_acc: 0.2305 - val_gender_output_acc: 0.8992
# Epoch 5/25
# 141/141 [==============================] - 22s 154ms/step - loss: -12.3287 - age_output_loss: 0.0263 - race_output_loss: 12.5065 - gender_output_loss: 0.1516 - age_output_mean_absolute_error: 0.1282 - race_output_acc: 0.2241 - gender_output_acc: 0.9437 - val_loss: -12.0997 - val_age_output_loss: 0.0258 - val_race_output_loss: 12.3992 - val_gender_output_loss: 0.2736 - val_age_output_mean_absolute_error: 0.1243 - val_race_output_acc: 0.2307 - val_gender_output_acc: 0.9130
# Epoch 6/25
# 141/141 [==============================] - 21s 151ms/step - loss: -12.3578 - age_output_loss: 0.0250 - race_output_loss: 12.5137 - gender_output_loss: 0.1309 - age_output_mean_absolute_error: 0.1248 - race_output_acc: 0.2236 - gender_output_acc: 0.9539 - val_loss: -11.4833 - val_age_output_loss: 0.0364 - val_race_output_loss: 12.1961 - val_gender_output_loss: 0.6764 - val_age_output_mean_absolute_error: 0.1454 - val_race_output_acc: 0.2302 - val_gender_output_acc: 0.7591
# Epoch 7/25
# 141/141 [==============================] - 21s 151ms/step - loss: -12.3835 - age_output_loss: 0.0230 - race_output_loss: 12.5119 - gender_output_loss: 0.1055 - age_output_mean_absolute_error: 0.1196 - race_output_acc: 0.2237 - gender_output_acc: 0.9624 - val_loss: -12.0944 - val_age_output_loss: 0.0370 - val_race_output_loss: 12.3950 - val_gender_output_loss: 0.2635 - val_age_output_mean_absolute_error: 0.1431 - val_race_output_acc: 0.2310 - val_gender_output_acc: 0.8924
# Epoch 8/25
# 141/141 [==============================] - 22s 153ms/step - loss: -12.3955 - age_output_loss: 0.0219 - race_output_loss: 12.5085 - gender_output_loss: 0.0911 - age_output_mean_absolute_error: 0.1160 - race_output_acc: 0.2238 - gender_output_acc: 0.9690 - val_loss: -12.0757 - val_age_output_loss: 0.0281 - val_race_output_loss: 12.4001 - val_gender_output_loss: 0.2963 - val_age_output_mean_absolute_error: 0.1272 - val_race_output_acc: 0.2305 - val_gender_output_acc: 0.9195
# Epoch 9/25
# 141/141 [==============================] - 22s 158ms/step - loss: -12.9951 - age_output_loss: 0.0220 - race_output_loss: 13.1119 - gender_output_loss: 0.0947 - age_output_mean_absolute_error: 0.1151 - race_output_acc: 0.1804 - gender_output_acc: 0.9671 - val_loss: -13.6458 - val_age_output_loss: 0.0267 - val_race_output_loss: 14.0011 - val_gender_output_loss: 0.3285 - val_age_output_mean_absolute_error: 0.1275 - val_race_output_acc: 0.1109 - val_gender_output_acc: 0.9047
# Epoch 10/25
# 141/141 [==============================] - 23s 164ms/step - loss: -15.2378 - age_output_loss: 0.0250 - race_output_loss: 15.4031 - gender_output_loss: 0.1402 - age_output_mean_absolute_error: 0.1240 - race_output_acc: 0.0341 - gender_output_acc: 0.9481 - val_loss: -15.1200 - val_age_output_loss: 0.0273 - val_race_output_loss: 15.4180 - val_gender_output_loss: 0.2707 - val_age_output_mean_absolute_error: 0.1310 - val_race_output_acc: 0.0326 - val_gender_output_acc: 0.9104
# Epoch 11/25
# 141/141 [==============================] - 21s 152ms/step - loss: -15.4288 - age_output_loss: 0.0246 - race_output_loss: 15.5815 - gender_output_loss: 0.1281 - age_output_mean_absolute_error: 0.1224 - race_output_acc: 0.0283 - gender_output_acc: 0.9535 - val_loss: -14.5114 - val_age_output_loss: 0.0777 - val_race_output_loss: 15.0507 - val_gender_output_loss: 0.4616 - val_age_output_mean_absolute_error: 0.2386 - val_race_output_acc: 0.0565 - val_gender_output_acc: 0.8154
# Epoch 12/25
# 141/141 [==============================] - 21s 149ms/step - loss: -15.4423 - age_output_loss: 0.0249 - race_output_loss: 15.6020 - gender_output_loss: 0.1348 - age_output_mean_absolute_error: 0.1224 - race_output_acc: 0.0275 - gender_output_acc: 0.9517 - val_loss: -15.2842 - val_age_output_loss: 0.0306 - val_race_output_loss: 15.5951 - val_gender_output_loss: 0.2803 - val_age_output_mean_absolute_error: 0.1318 - val_race_output_acc: 0.0271 - val_gender_output_acc: 0.9070
# Epoch 13/25
# 141/141 [==============================] - 21s 151ms/step - loss: -15.5426 - age_output_loss: 0.0244 - race_output_loss: 15.6894 - gender_output_loss: 0.1224 - age_output_mean_absolute_error: 0.1224 - race_output_acc: 0.0228 - gender_output_acc: 0.9538 - val_loss: -14.9786 - val_age_output_loss: 0.0262 - val_race_output_loss: 15.2754 - val_gender_output_loss: 0.2705 - val_age_output_mean_absolute_error: 0.1255 - val_race_output_acc: 0.0464 - val_gender_output_acc: 0.9099
# Epoch 14/25
# 141/141 [==============================] - 22s 157ms/step - loss: -15.5395 - age_output_loss: 0.0237 - race_output_loss: 15.6912 - gender_output_loss: 0.1279 - age_output_mean_absolute_error: 0.1205 - race_output_acc: 0.0228 - gender_output_acc: 0.9518 - val_loss: -15.0928 - val_age_output_loss: 0.0317 - val_race_output_loss: 15.6689 - val_gender_output_loss: 0.5444 - val_age_output_mean_absolute_error: 0.1463 - val_race_output_acc: 0.0247 - val_gender_output_acc: 0.8542
# Epoch 15/25
# 141/141 [==============================] - 22s 159ms/step - loss: -15.6353 - age_output_loss: 0.0229 - race_output_loss: 15.7650 - gender_output_loss: 0.1067 - age_output_mean_absolute_error: 0.1178 - race_output_acc: 0.0188 - gender_output_acc: 0.9608 - val_loss: -15.0878 - val_age_output_loss: 0.0266 - val_race_output_loss: 15.6365 - val_gender_output_loss: 0.5222 - val_age_output_mean_absolute_error: 0.1303 - val_race_output_acc: 0.0245 - val_gender_output_acc: 0.8365
# Epoch 16/25
# 141/141 [==============================] - 22s 159ms/step - loss: -15.5606 - age_output_loss: 0.0237 - race_output_loss: 15.7028 - gender_output_loss: 0.1185 - age_output_mean_absolute_error: 0.1194 - race_output_acc: 0.0224 - gender_output_acc: 0.9564 - val_loss: -14.9084 - val_age_output_loss: 0.0315 - val_race_output_loss: 15.1906 - val_gender_output_loss: 0.2507 - val_age_output_mean_absolute_error: 0.1431 - val_race_output_acc: 0.0503 - val_gender_output_acc: 0.9062
# Epoch 17/25
# 141/141 [==============================] - 23s 163ms/step - loss: -15.6973 - age_output_loss: 0.0231 - race_output_loss: 15.8169 - gender_output_loss: 0.0965 - age_output_mean_absolute_error: 0.1176 - race_output_acc: 0.0168 - gender_output_acc: 0.9633 - val_loss: -15.0183 - val_age_output_loss: 0.0301 - val_race_output_loss: 15.4401 - val_gender_output_loss: 0.3917 - val_age_output_mean_absolute_error: 0.1350 - val_race_output_acc: 0.0346 - val_gender_output_acc: 0.8625
# Epoch 18/25
# 141/141 [==============================] - 22s 155ms/step - loss: -15.7323 - age_output_loss: 0.0224 - race_output_loss: 15.8367 - gender_output_loss: 0.0820 - age_output_mean_absolute_error: 0.1161 - race_output_acc: 0.0156 - gender_output_acc: 0.9714 - val_loss: -15.4477 - val_age_output_loss: 0.0270 - val_race_output_loss: 15.7765 - val_gender_output_loss: 0.3018 - val_age_output_mean_absolute_error: 0.1317 - val_race_output_acc: 0.0193 - val_gender_output_acc: 0.9211
# Epoch 19/25
# 141/141 [==============================] - 21s 151ms/step - loss: -15.7255 - age_output_loss: 0.0223 - race_output_loss: 15.8317 - gender_output_loss: 0.0839 - age_output_mean_absolute_error: 0.1156 - race_output_acc: 0.0163 - gender_output_acc: 0.9724 - val_loss: -15.1163 - val_age_output_loss: 0.0253 - val_race_output_loss: 15.4924 - val_gender_output_loss: 0.3508 - val_age_output_mean_absolute_error: 0.1228 - val_race_output_acc: 0.0333 - val_gender_output_acc: 0.9133
# Epoch 20/25
# 141/141 [==============================] - 21s 149ms/step - loss: -15.7426 - age_output_loss: 0.0219 - race_output_loss: 15.8411 - gender_output_loss: 0.0766 - age_output_mean_absolute_error: 0.1149 - race_output_acc: 0.0156 - gender_output_acc: 0.9743 - val_loss: -15.0548 - val_age_output_loss: 0.0318 - val_race_output_loss: 15.4634 - val_gender_output_loss: 0.3769 - val_age_output_mean_absolute_error: 0.1333 - val_race_output_acc: 0.0354 - val_gender_output_acc: 0.8797
# Epoch 21/25
# 141/141 [==============================] - 22s 153ms/step - loss: -15.7558 - age_output_loss: 0.0218 - race_output_loss: 15.8510 - gender_output_loss: 0.0734 - age_output_mean_absolute_error: 0.1140 - race_output_acc: 0.0155 - gender_output_acc: 0.9746 - val_loss: -14.7578 - val_age_output_loss: 0.0302 - val_race_output_loss: 15.6533 - val_gender_output_loss: 0.8653 - val_age_output_mean_absolute_error: 0.1305 - val_race_output_acc: 0.0255 - val_gender_output_acc: 0.8010
# Epoch 22/25
# 141/141 [==============================] - 21s 152ms/step - loss: -15.7226 - age_output_loss: 0.0208 - race_output_loss: 15.8167 - gender_output_loss: 0.0733 - age_output_mean_absolute_error: 0.1116 - race_output_acc: 0.0171 - gender_output_acc: 0.9752 - val_loss: -14.7238 - val_age_output_loss: 0.0279 - val_race_output_loss: 15.0429 - val_gender_output_loss: 0.2913 - val_age_output_mean_absolute_error: 0.1368 - val_race_output_acc: 0.0609 - val_gender_output_acc: 0.9164
# Epoch 23/25
# 141/141 [==============================] - 21s 152ms/step - loss: -15.7829 - age_output_loss: 0.0212 - race_output_loss: 15.8695 - gender_output_loss: 0.0655 - age_output_mean_absolute_error: 0.1132 - race_output_acc: 0.0145 - gender_output_acc: 0.9777 - val_loss: -14.3878 - val_age_output_loss: 0.0423 - val_race_output_loss: 14.7799 - val_gender_output_loss: 0.3499 - val_age_output_mean_absolute_error: 0.1517 - val_race_output_acc: 0.0750 - val_gender_output_acc: 0.8508
# Epoch 24/25
# 141/141 [==============================] - 21s 152ms/step - loss: -15.8016 - age_output_loss: 0.0215 - race_output_loss: 15.8863 - gender_output_loss: 0.0631 - age_output_mean_absolute_error: 0.1132 - race_output_acc: 0.0130 - gender_output_acc: 0.9775 - val_loss: -14.9734 - val_age_output_loss: 0.0315 - val_race_output_loss: 15.5282 - val_gender_output_loss: 0.5233 - val_age_output_mean_absolute_error: 0.1398 - val_race_output_acc: 0.0346 - val_gender_output_acc: 0.8536
# Epoch 25/25
# 141/141 [==============================] - 22s 153ms/step - loss: -15.8239 - age_output_loss: 0.0206 - race_output_loss: 15.8997 - gender_output_loss: 0.0552 - age_output_mean_absolute_error: 0.1112 - race_output_acc: 0.0124 - gender_output_acc: 0.9798 - val_loss: -15.3986 - val_age_output_loss: 0.0232 - val_race_output_loss: 15.8167 - val_gender_output_loss: 0.3948 - val_age_output_mean_absolute_error: 0.1148 - val_race_output_acc: 0.0169 - val_gender_output_acc: 0.9224

# %%
def  plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['race_output_acc'], label='Race Train accuracy')
    axes[0].plot(history.history['val_race_output_acc'], label='Race Val accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()
    
    axes[1].plot(history.history['gender_output_acc'], label='Gender Train accuracy')
    axes[1].plot(history.history['val_gender_output_acc'], label='Gener Val accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['age_output_mean_absolute_error'], label='Age Train MAE')
    axes[2].plot(history.history['val_age_output_mean_absolute_error'], label='Age Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
dict(zip(model.metrics_names, model.evaluate_generator(test_gen, steps=len(test_idx)//128)))
# Out:
# {'loss': -12.09016425110573,
#  'age_output_loss': 0.03593596170634725,
#  'race_output_loss': 12.571762883385947,
#  'gender_output_loss': 0.4456627112488414,
#  'age_output_mean_absolute_error': 0.14331335557061572,
#  'race_output_acc': 0.22002180232558138,
#  'gender_output_acc': 0.7990552325581395}

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
x_test, (age_true, race_true, gender_true)= next(test_gen)
age_pred, race_pred, gender_pred = model.predict_on_batch(x_test)

# %%
race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)
age_true = age_true * max_age
age_pred = age_pred * max_age

# %%
from sklearn.metrics import classification_report
print("Classification report for race")
print(classification_report(race_true, race_pred))

print("\nClassification report for gender")
print(classification_report(gender_true, gender_pred))
# Out:
# Classification report for race
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        55
#            1       0.21      1.00      0.35        27
#            2       0.00      0.00      0.00        16
#            3       0.00      0.00      0.00        19
#            4       0.00      0.00      0.00        11
#
#    micro avg       0.21      0.21      0.21       128
#    macro avg       0.04      0.20      0.07       128
# weighted avg       0.04      0.21      0.07       128
#
#
# Classification report for gender
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        81
#            1       0.88      0.79      0.83        47
#
#    micro avg       0.88      0.88      0.88       128
#    macro avg       0.88      0.86      0.87       128
# weighted avg       0.88      0.88      0.88       128
# /home/indu/tfenv/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import math
n = 30
random_indices = np.random.permutation(n)
n_cols = 5
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 20))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(x_test[img_idx])
    ax.set_title('a:{}, g:{}, r:{}'.format(int(age_pred[img_idx]), ID_GENDER_MAP[gender_pred[img_idx]], ID_RACE_MAP[race_pred[img_idx]]))
    ax.set_xlabel('a:{}, g:{}, r:{}'.format(int(age_true[img_idx]), ID_GENDER_MAP[gender_true[img_idx]], ID_RACE_MAP[race_true[img_idx]]))
    ax.set_xticks([])
    ax.set_yticks([])
