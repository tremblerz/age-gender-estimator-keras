# %% [markdown]
# UTKFace dataset is a large-scale face dataset with long age span (range from 0 to 116 years old). The dataset consists of over 20,000 face images with annotations of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc. This dataset could be used on a variety of tasks, e.g., face detection, age estimation, age progression/regression, landmark localization, etc.
#
# The labels of each face image is embedded in the file name, formated like [age]_[gender]_[race]_[date&time].jpg
#
# [age] is an integer from 0 to 116, indicating the age
# [gender] is either 0 (male) or 1 (female)
# [race] is an integer from 0 to 4, denoting White, Black, Asian, Indian, and Others (like Hispanic, Latino, Middle Eastern).
# [date&time] is in the format of yyyymmddHHMMSSFFF, showing the date and time an image was collected to UTKFace

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%bash
# ls data
# # it seems crop_part1 conists of subset of data contained in UTKFace so we won't be using it.
# Out:
# UTKFace
# UTKFace.tar.gz

# %% [markdown]
# **Constants**

# %%
DATA_DIR = "data/UTKFace"
TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198
ID_GENDER_MAP = {0: 'male', 1: 'female'}
GENDER_ID_MAP = dict((g, i) for i, g in ID_GENDER_MAP.items())
ID_RACE_MAP = {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'}
RACE_ID_MAP = dict((r, i) for i, r in ID_RACE_MAP.items())

ID_GENDER_MAP, GENDER_ID_MAP, ID_RACE_MAP, RACE_ID_MAP
# Out:
# ({0: 'male', 1: 'female'},
#  {'male': 0, 'female': 1},
#  {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
#  {'white': 0, 'black': 1, 'asian': 2, 'indian': 3, 'others': 4})

# %%
def parse_filepath(filepath):
    try:
        path, filename = os.path.split(filepath)
        filename, ext = os.path.splitext(filename)
        age, gender, race, _ = filename.split("_")
        return int(age), ID_GENDER_MAP[int(gender)], ID_RACE_MAP[int(race)]
    except Exception as e:
        print(filepath)
        return None, None, None

# %%
# create a pandas data frame of images, age, gender and race
files = glob.glob(os.path.join(DATA_DIR, "*.jpg"))

# %%
attributes = list(map(parse_filepath, files))
# Out:
# data/UTKFace/39_1_20170116174525125.jpg.chip.jpg
# data/UTKFace/61_1_20170109150557335.jpg.chip.jpg
# data/UTKFace/61_1_20170109142408075.jpg.chip.jpg

# %%
df = pd.DataFrame(attributes)
df['file'] = files
df.columns = ['age', 'gender', 'race', 'file']
df = df.dropna()
df.head()
# Out:
#     age  gender    race                                               file
# 0  65.0    male  indian  data/UTKFace/65_0_3_20170119205206575.jpg.chip...
# 1  16.0    male   white  data/UTKFace/16_0_0_20170110232429214.jpg.chip...
# 2  52.0    male   white  data/UTKFace/52_0_0_20170111195726274.jpg.chip...
# 3  18.0  female   white  data/UTKFace/18_1_0_20170109212921724.jpg.chip...
# 4  57.0  female   white  data/UTKFace/57_1_0_20170120221057091.jpg.chip...

# %% [markdown]
# # Exploratory analysis

# %%
df.describe()
# Out:
#                 age
# count  23705.000000
# mean      33.300907
# std       19.885708
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %% [markdown]
# From the plot we can see that most of people are within 10 and 55 years of age. Most probably, we'll discard the dataset for rest of the ages.

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='gender', y='age', hue='race')

# %%
df.groupby(by=['race', 'gender'])['age'].count().plot(kind='bar')

# %% [markdown]
# It turns out that there are many images of *white male* and *while female*. images from *others* category are very less in number compared to rest of the categories especially *white* category.
# Let's analyze our data from *age* perspective.

# %%
df['age'].hist()

# %%
df['age'].describe()
# Out:
# count    23705.000000
# mean        33.300907
# std         19.885708
# min          1.000000
# 25%         23.000000
# 50%         29.000000
# 75%         45.000000
# max        116.000000
# Name: age, dtype: float64

# %%
df = df[(df['age'] > 10) & (df['age'] < 65)]

# %% [markdown]
# # Data prep

# %%
p = np.random.permutation(len(df))
train_up_to = int(len(df) * TRAIN_TEST_SPLIT)
train_idx = p[:train_up_to]
test_idx = p[train_up_to:]

# split train_idx further into training and validation set
train_up_to = int(train_up_to * 0.7)
train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]

df['gender_id'] = df['gender'].map(lambda gender: GENDER_ID_MAP[gender])
df['race_id'] = df['race'].map(lambda race: RACE_ID_MAP[race])

max_age = df['age'].max()
len(train_idx), len(valid_idx), len(test_idx), max_age
# Out:
# (9079, 3891, 5559, 64.0)

# %%
from keras.utils import to_categorical
from PIL import Image

def get_data_generator(df, indices, for_training, batch_size=16):
    images, ages, races, genders = [], [], [], []
    while True:
        for i in indices:
            r = df.iloc[i]
            file, age, race, gender = r['file'], r['age'], r['race_id'], r['gender_id']
            im = Image.open(file)
            im = im.resize((IM_WIDTH, IM_HEIGHT))
            im = np.array(im) / 255.0
            images.append(im)
            ages.append(age / max_age)
            races.append(to_categorical(race, len(RACE_ID_MAP)))
            genders.append(to_categorical(gender, 2))
            if len(images) >= batch_size:
                yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
                images, ages, races, genders = [], [], [], []
        if not for_training:
            break
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Model training

# %%
from keras.layers import Input, Dense, BatchNormalization, Conv2D, MaxPool2D, GlobalMaxPool2D, Dropout
from keras.optimizers import SGD
from keras.models import Model

def conv_block(inp, filters=32, bn=True, pool=True):
    _ = Conv2D(filters=filters, kernel_size=3, activation='relu')(inp)
    if bn:
        _ = BatchNormalization()(_)
    if pool:
        _ = MaxPool2D()(_)
    return _

input_layer = Input(shape=(IM_HEIGHT, IM_WIDTH, 3))
_ = conv_block(input_layer, filters=32, bn=False, pool=False)
_ = conv_block(_, filters=32*2)
_ = conv_block(_, filters=32*3)
_ = conv_block(_, filters=32*4)
_ = conv_block(_, filters=32*5)
_ = conv_block(_, filters=32*6)
bottleneck = GlobalMaxPool2D()(_)

# for age calculation
_ = Dense(units=128, activation='relu')(bottleneck)
age_output = Dense(units=1, activation='sigmoid', name='age_output')(_)

# for race prediction
_ = Dense(units=128, activation='relu')(bottleneck)
race_output = Dense(units=len(RACE_ID_MAP), activation='softmax', name='race_output')(_)

# for gender prediction
_ = Dense(units=128, activation='relu')(bottleneck)
gender_output = Dense(units=len(GENDER_ID_MAP), activation='softmax', name='gender_output')(_)

model = Model(inputs=input_layer, outputs=[age_output, race_output, gender_output])
model.compile(optimizer='rmsprop', 
              loss={'age_output': 'mse', 'race_output': 'categorical_crossentropy', 'gender_output': 'categorical_crossentropy'},
              loss_weights={'age_output': 2., 'race_output': 1.5, 'gender_output': 1.},
              metrics={'age_output': 'mae', 'race_output': 'accuracy', 'gender_output': 'accuracy'})
# model.summary()

# %%
from keras.callbacks import ModelCheckpoint

batch_size = 64
valid_batch_size = 64
train_gen = get_data_generator(df, train_idx, for_training=True, batch_size=batch_size)
valid_gen = get_data_generator(df, valid_idx, for_training=True, batch_size=valid_batch_size)

callbacks = [
    ModelCheckpoint("./original_model.h5", monitor='val_loss')
]

history = model.fit_generator(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=10,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size)
# Out:
# Epoch 1/10
# 141/141 [==============================] - 25s 175ms/step - loss: 2.8375 - age_output_loss: 0.0573 - race_output_loss: 1.3864 - gender_output_loss: 0.6431 - age_output_mean_absolute_error: 0.1914 - race_output_acc: 0.4881 - gender_output_acc: 0.7202 - val_loss: 3.2610 - val_age_output_loss: 0.0828 - val_race_output_loss: 1.7963 - val_gender_output_loss: 0.4009 - val_age_output_mean_absolute_error: 0.2323 - val_race_output_acc: 0.3911 - val_gender_output_acc: 0.8255
# Epoch 2/10
# 141/141 [==============================] - 22s 154ms/step - loss: 1.8753 - age_output_loss: 0.0356 - race_output_loss: 0.9777 - gender_output_loss: 0.3375 - age_output_mean_absolute_error: 0.1505 - race_output_acc: 0.6402 - gender_output_acc: 0.8588 - val_loss: 1.9117 - val_age_output_loss: 0.0377 - val_race_output_loss: 0.9062 - val_gender_output_loss: 0.4771 - val_age_output_mean_absolute_error: 0.1608 - val_race_output_acc: 0.6633 - val_gender_output_acc: 0.8172
# Epoch 3/10
# 141/141 [==============================] - 22s 156ms/step - loss: 1.5039 - age_output_loss: 0.0315 - race_output_loss: 0.7903 - gender_output_loss: 0.2555 - age_output_mean_absolute_error: 0.1408 - race_output_acc: 0.7175 - gender_output_acc: 0.8957 - val_loss: 1.6031 - val_age_output_loss: 0.0296 - val_race_output_loss: 0.8559 - val_gender_output_loss: 0.2601 - val_age_output_mean_absolute_error: 0.1341 - val_race_output_acc: 0.6805 - val_gender_output_acc: 0.9013
# Epoch 4/10
# 141/141 [==============================] - 22s 159ms/step - loss: 1.2703 - age_output_loss: 0.0282 - race_output_loss: 0.6675 - gender_output_loss: 0.2128 - age_output_mean_absolute_error: 0.1323 - race_output_acc: 0.7629 - gender_output_acc: 0.9211 - val_loss: 1.6327 - val_age_output_loss: 0.0371 - val_race_output_loss: 0.7680 - val_gender_output_loss: 0.4065 - val_age_output_mean_absolute_error: 0.1625 - val_race_output_acc: 0.7214 - val_gender_output_acc: 0.8318
# Epoch 5/10
# 141/141 [==============================] - 22s 154ms/step - loss: 1.0876 - age_output_loss: 0.0266 - race_output_loss: 0.5711 - gender_output_loss: 0.1777 - age_output_mean_absolute_error: 0.1286 - race_output_acc: 0.8019 - gender_output_acc: 0.9350 - val_loss: 1.3140 - val_age_output_loss: 0.0273 - val_race_output_loss: 0.7019 - val_gender_output_loss: 0.2064 - val_age_output_mean_absolute_error: 0.1295 - val_race_output_acc: 0.7531 - val_gender_output_acc: 0.9255
# Epoch 6/10
# 141/141 [==============================] - 22s 158ms/step - loss: 0.9516 - age_output_loss: 0.0252 - race_output_loss: 0.4957 - gender_output_loss: 0.1576 - age_output_mean_absolute_error: 0.1245 - race_output_acc: 0.8246 - gender_output_acc: 0.9402 - val_loss: 1.3701 - val_age_output_loss: 0.0262 - val_race_output_loss: 0.7001 - val_gender_output_loss: 0.2676 - val_age_output_mean_absolute_error: 0.1244 - val_race_output_acc: 0.7620 - val_gender_output_acc: 0.8953
# Epoch 7/10
# 141/141 [==============================] - 22s 159ms/step - loss: 0.7860 - age_output_loss: 0.0242 - race_output_loss: 0.4047 - gender_output_loss: 0.1305 - age_output_mean_absolute_error: 0.1215 - race_output_acc: 0.8584 - gender_output_acc: 0.9508 - val_loss: 1.3783 - val_age_output_loss: 0.0287 - val_race_output_loss: 0.7219 - val_gender_output_loss: 0.2380 - val_age_output_mean_absolute_error: 0.1372 - val_race_output_acc: 0.7477 - val_gender_output_acc: 0.9148
# Epoch 8/10
# 141/141 [==============================] - 22s 159ms/step - loss: 0.6549 - age_output_loss: 0.0234 - race_output_loss: 0.3321 - gender_output_loss: 0.1100 - age_output_mean_absolute_error: 0.1196 - race_output_acc: 0.8840 - gender_output_acc: 0.9611 - val_loss: 1.7868 - val_age_output_loss: 0.0315 - val_race_output_loss: 0.9497 - val_gender_output_loss: 0.2993 - val_age_output_mean_absolute_error: 0.1428 - val_race_output_acc: 0.6396 - val_gender_output_acc: 0.8849
# Epoch 9/10
# 141/141 [==============================] - 22s 159ms/step - loss: 0.5578 - age_output_loss: 0.0227 - race_output_loss: 0.2746 - gender_output_loss: 0.1005 - age_output_mean_absolute_error: 0.1181 - race_output_acc: 0.9034 - gender_output_acc: 0.9659 - val_loss: 2.2612 - val_age_output_loss: 0.0302 - val_race_output_loss: 1.2687 - val_gender_output_loss: 0.2978 - val_age_output_mean_absolute_error: 0.1349 - val_race_output_acc: 0.6258 - val_gender_output_acc: 0.8854
# Epoch 10/10
# 141/141 [==============================] - 22s 158ms/step - loss: 0.4720 - age_output_loss: 0.0222 - race_output_loss: 0.2286 - gender_output_loss: 0.0847 - age_output_mean_absolute_error: 0.1162 - race_output_acc: 0.9168 - gender_output_acc: 0.9697 - val_loss: 1.7865 - val_age_output_loss: 0.0309 - val_race_output_loss: 0.9553 - val_gender_output_loss: 0.2918 - val_age_output_mean_absolute_error: 0.1375 - val_race_output_acc: 0.6711 - val_gender_output_acc: 0.8964

# %%
def  plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['race_output_acc'], label='Race Train accuracy')
    axes[0].plot(history.history['val_race_output_acc'], label='Race Val accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()
    
    axes[1].plot(history.history['gender_output_acc'], label='Gender Train accuracy')
    axes[1].plot(history.history['val_gender_output_acc'], label='Gener Val accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['age_output_mean_absolute_error'], label='Age Train MAE')
    axes[2].plot(history.history['val_age_output_mean_absolute_error'], label='Age Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
dict(zip(model.metrics_names, model.evaluate_generator(test_gen, steps=len(test_idx)//128)))
# Out:
# {'loss': 1.784742887630019,
#  'age_output_loss': 0.03107928506336933,
#  'race_output_loss': 0.9586920460989309,
#  'gender_output_loss': 0.2845462439365165,
#  'age_output_mean_absolute_error': 0.13867722555648448,
#  'race_output_acc': 0.6780523255813954,
#  'gender_output_acc': 0.8904433139534884}

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
x_test, (age_true, race_true, gender_true)= next(test_gen)
age_pred, race_pred, gender_pred = model.predict_on_batch(x_test)

# %%
race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)
age_true = age_true * max_age
age_pred = age_pred * max_age

# %%
from sklearn.metrics import classification_report
print("Classification report for race")
print(classification_report(race_true, race_pred))

print("\nClassification report for gender")
print(classification_report(gender_true, gender_pred))
# Out:
# Classification report for race
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.78        48
#            1       0.94      0.58      0.71        26
#            2       0.62      0.81      0.70        16
#            3       0.64      0.69      0.67        26
#            4       0.25      0.17      0.20        12
#
#    micro avg       0.69      0.69      0.69       128
#    macro avg       0.64      0.62      0.61       128
# weighted avg       0.69      0.69      0.68       128
#
#
# Classification report for gender
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86        57
#            1       0.92      0.83      0.87        71
#
#    micro avg       0.87      0.87      0.87       128
#    macro avg       0.87      0.87      0.87       128
# weighted avg       0.87      0.87      0.87       128

# %%
import math
n = 30
random_indices = np.random.permutation(n)
n_cols = 5
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 20))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(x_test[img_idx])
    ax.set_title('a:{}, g:{}, r:{}'.format(int(age_pred[img_idx]), ID_GENDER_MAP[gender_pred[img_idx]], ID_RACE_MAP[race_pred[img_idx]]))
    ax.set_xlabel('a:{}, g:{}, r:{}'.format(int(age_true[img_idx]), ID_GENDER_MAP[gender_true[img_idx]], ID_RACE_MAP[race_true[img_idx]]))
    ax.set_xticks([])
    ax.set_yticks([])
